# %%
# !git clone https://github.com/trextrader/hotdogornot
# Out:
# Cloning into 'hotdogornot'...
# remote: Enumerating objects: 16247, done.
# remote: Counting objects: 100% (304/304), done.
# remote: Compressing objects: 100% (250/250), done.
# remote: Total 16247 (delta 125), reused 225 (delta 51), pack-reused 15943 (from 2)
# Receiving objects: 100% (16247/16247), 545.22 MiB | 40.48 MiB/s, done.
# Resolving deltas: 100% (2213/2213), done.
# Updating files: 100% (14465/14465), done.

# %%
cd hotdogornot/
# Out:
# /content/hotdogornot

# %%
cd training
# Out:
# /content/hotdogornot/training

# %%
# @title
# !pip install -e ".[dev]"
# Out:
# Obtaining file:///content/hotdogornot/training
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4>=4.12 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (4.13.5)
# Collecting ddgs>=4.0 (from rfconnectorai==0.1.0)
#   Downloading ddgs-9.14.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: fastapi>=0.110 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (0.136.1)
# Requirement already satisfied: httpx>=0.27 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (0.28.1)
# Collecting icrawler>=0.6 (from rfconnectorai==0.1.0)
#   Downloading icrawler-0.6.10-py3-none-any.whl.metadata (6.2 kB)
# Collecting imagehash>=4.3 (from rfconnectorai==0.1.0)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: jinja2>=3.1 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (3.1.6)
# Requirement already satisfied: matplotlib>=3.8 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (3.10.0)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (2.0.2)
# Collecting onnx>=1.16 (from rfconnectorai==0.1.0)
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Collecting onnxruntime>=1.18 (from rfconnectorai==0.1.0)
#   Downloading onnxruntime-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: opencv-python-headless>=4.9 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (4.13.0.92)
# Requirement already satisfied: pillow>=10.0 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (11.3.0)
# Requirement already satisfied: python-dotenv>=1.0 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (1.2.2)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (0.0.26)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (6.0.3)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (2.32.4)
# Requirement already satisfied: scikit-learn>=1.4 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (1.6.1)
# Requirement already satisfied: scipy>=1.11 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (1.16.3)
# Collecting streamlit>=1.30 (from rfconnectorai==0.1.0)
#   Downloading streamlit-1.57.0-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: timm>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (1.0.26)
# Requirement already satisfied: torch<3.0,>=2.2 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (2.10.0+cu128)
# Requirement already satisfied: torchvision<1.0,>=0.17 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (0.25.0+cu128)
# Collecting trimesh>=4.0 (from rfconnectorai==0.1.0)
#   Downloading trimesh-4.12.2-py3-none-any.whl.metadata (13 kB)
# Collecting ultralytics>=8.2.0 (from rfconnectorai==0.1.0)
#   Downloading ultralytics-8.4.48-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: uvicorn>=0.27 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27->rfconnectorai==0.1.0) (0.46.0)
# Collecting pytest-cov>=5.0 (from rfconnectorai==0.1.0)
#   Downloading pytest_cov-7.1.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: pytest>=8.0 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (8.4.2)
# Requirement already satisfied: ruff>=0.4 in /usr/local/lib/python3.12/dist-packages (from rfconnectorai==0.1.0) (0.15.11)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.12->rfconnectorai==0.1.0) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.12->rfconnectorai==0.1.0) (4.15.0)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from ddgs>=4.0->rfconnectorai==0.1.0) (8.3.3)
# Collecting primp>=1.2.3 (from ddgs>=4.0->rfconnectorai==0.1.0)
#   Downloading primp-1.2.3-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: lxml>=4.9.4 in /usr/local/lib/python3.12/dist-packages (from ddgs>=4.0->rfconnectorai==0.1.0) (6.1.0)
# Requirement already satisfied: starlette>=0.46.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.110->rfconnectorai==0.1.0) (0.52.1)
# Requirement already satisfied: pydantic>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.110->rfconnectorai==0.1.0) (2.12.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.110->rfconnectorai==0.1.0) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.110->rfconnectorai==0.1.0) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->rfconnectorai==0.1.0) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->rfconnectorai==0.1.0) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->rfconnectorai==0.1.0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->rfconnectorai==0.1.0) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27->rfconnectorai==0.1.0) (0.16.0)
# Collecting bs4 (from icrawler>=0.6->rfconnectorai==0.1.0)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from icrawler>=0.6->rfconnectorai==0.1.0) (1.17.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.12/dist-packages (from imagehash>=4.3->rfconnectorai==0.1.0) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1->rfconnectorai==0.1.0) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->rfconnectorai==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->rfconnectorai==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->rfconnectorai==0.1.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->rfconnectorai==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->rfconnectorai==0.1.0) (26.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->rfconnectorai==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->rfconnectorai==0.1.0) (2.9.0.post0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.16->rfconnectorai==0.1.0) (5.29.6)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.16->rfconnectorai==0.1.0) (0.5.4)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.18->rfconnectorai==0.1.0) (25.12.19)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.0->rfconnectorai==0.1.0) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.0->rfconnectorai==0.1.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.0->rfconnectorai==0.1.0) (2.20.0)
# Collecting coverage>=7.10.6 (from coverage[toml]>=7.10.6->pytest-cov>=5.0->rfconnectorai==0.1.0)
#   Downloading coverage-7.13.5-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->rfconnectorai==0.1.0) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->rfconnectorai==0.1.0) (2.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->rfconnectorai==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->rfconnectorai==0.1.0) (3.6.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.30->rfconnectorai==0.1.0) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.30->rfconnectorai==0.1.0) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.30->rfconnectorai==0.1.0) (6.2.6)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.30->rfconnectorai==0.1.0) (3.1.47)
# Requirement already satisfied: pandas<4,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.30->rfconnectorai==0.1.0) (2.2.2)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit>=1.30->rfconnectorai==0.1.0)
#   Downloading pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.30->rfconnectorai==0.1.0) (18.1.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.30->rfconnectorai==0.1.0) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.30->rfconnectorai==0.1.0) (0.10.2)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.30->rfconnectorai==0.1.0) (0.7.1)
# Requirement already satisfied: websockets>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.30->rfconnectorai==0.1.0) (15.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.30->rfconnectorai==0.1.0) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.30->rfconnectorai==0.1.0) (6.0.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm>=1.0.0->rfconnectorai==0.1.0) (1.11.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm>=1.0.0->rfconnectorai==0.1.0) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (3.29.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.2->rfconnectorai==0.1.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3.0,>=2.2->rfconnectorai==0.1.0) (1.5.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.2.0->rfconnectorai==0.1.0) (4.13.0.92)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.2.0->rfconnectorai==0.1.0) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.2.0->rfconnectorai==0.1.0) (1.35.2)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics>=8.2.0->rfconnectorai==0.1.0)
#   Downloading ultralytics_thop-2.0.19-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27->rfconnectorai==0.1.0) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27->rfconnectorai==0.1.0) (1.1.1)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30->rfconnectorai==0.1.0) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30->rfconnectorai==0.1.0) (2.20.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.30->rfconnectorai==0.1.0) (4.0.12)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=1.4.0->streamlit>=1.30->rfconnectorai==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=1.4.0->streamlit>=1.30->rfconnectorai==0.1.0) (2026.1)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics>=8.2.0->rfconnectorai==0.1.0) (1.35.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.0->fastapi>=0.110->rfconnectorai==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.0->fastapi>=0.110->rfconnectorai==0.1.0) (2.41.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.2->rfconnectorai==0.1.0) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm>=1.0.0->rfconnectorai==0.1.0) (1.4.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm>=1.0.0->rfconnectorai==0.1.0) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm>=1.0.0->rfconnectorai==0.1.0) (0.24.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.30->rfconnectorai==0.1.0) (5.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30->rfconnectorai==0.1.0) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30->rfconnectorai==0.1.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30->rfconnectorai==0.1.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30->rfconnectorai==0.1.0) (0.30.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm>=1.0.0->rfconnectorai==0.1.0) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm>=1.0.0->rfconnectorai==0.1.0) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->timm>=1.0.0->rfconnectorai==0.1.0) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->timm>=1.0.0->rfconnectorai==0.1.0) (0.1.2)
# Downloading ddgs-9.14.2-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 6.4 MB/s eta 0:00:00
# Downloading icrawler-0.6.10-py3-none-any.whl (36 kB)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 13.4 MB/s eta 0:00:00
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 72.9 MB/s eta 0:00:00
# Downloading onnxruntime-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 70.2 MB/s eta 0:00:00
# Downloading pytest_cov-7.1.0-py3-none-any.whl (22 kB)
# Downloading streamlit-1.57.0-py3-none-any.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 62.4 MB/s eta 0:00:00
# Downloading trimesh-4.12.2-py3-none-any.whl (741 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 741.0/741.0 kB 38.7 MB/s eta 0:00:00
# Downloading ultralytics-8.4.48-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 66.8 MB/s eta 0:00:00
# Downloading coverage-7.13.5-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.2/254.2 kB 15.3 MB/s eta 0:00:00
# Downloading primp-1.2.3-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 82.0 MB/s eta 0:00:00
# Downloading pydeck-0.9.2-py2.py3-none-any.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 87.0 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.19-py3-none-any.whl (28 kB)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Building wheels for collected packages: rfconnectorai
#   Building editable for rfconnectorai (pyproject.toml) ... done
#   Created wheel for rfconnectorai: filename=rfconnectorai-0.1.0-py3-none-any.whl size=1419 sha256=734dd19f12e07e19ae1d25f237084bec5d574d8c6d3b1ca78294de5d91be7c47
#   Stored in directory: /tmp/pip-ephem-wheel-cache-szrh53zb/wheels/3b/ac/cd/b6bca6a547c755dbdfd5b88fac5a137fb63d02b6acb225621a
# Successfully built rfconnectorai
# Installing collected packages: trimesh, primp, onnxruntime, coverage, pydeck, onnx, imagehash, ddgs, bs4, pytest-cov, icrawler, ultralytics-thop, ultralytics, streamlit, rfconnectorai
# Successfully installed bs4-0.0.2 coverage-7.13.5 ddgs-9.14.2 icrawler-0.6.10 imagehash-4.3.2 onnx-1.21.0 onnxruntime-1.26.0 primp-1.2.3 pydeck-0.9.2 pytest-cov-7.1.0 rfconnectorai-0.1.0 streamlit-1.57.0 trimesh-4.12.2 ultralytics-8.4.48 ultralytics-thop-2.0.19

# %%
# !git pull
# Out:
# Already up to date.

# %%
# %cd /content/hotdogornot
# !pwd
# !ls training/data/labeled/embedder | head
# Out:
# /content/hotdogornot
# /content/hotdogornot
# 2.4mm-F
# 2.4mm-M
# 2.92mm-F
# 2.92mm-M
# 3.5mm-F
# 3.5mm-M

# %%
# %%shell
#   set -euxo pipefail
#   cd /content/hotdogornot
#   export PYTHONPATH=/content/hotdogornot/training
#   export PYTHONUNBUFFERED=1
#
#   python -u -m rfconnectorai.data.audit \
#       --data-dir training --out docs/DATASET_AUDIT.md
#
#   echo "----- audit summary -----"
#   head -40 docs/DATASET_AUDIT.md
#
#   python -u -m rfconnectorai.data.crop_instances \
#       --input training/data/labeled/embedder \
#       --manifest datasets/rfconnectors/instances.jsonl \
#       --out datasets/rfconnectors/crops \
#       --mode whole-image --base-dir training
#
#   wc -l datasets/rfconnectors/instances.jsonl
# Out:
# + cd /content/hotdogornot
# + export PYTHONPATH=/content/hotdogornot/training
# + PYTHONPATH=/content/hotdogornot/training
# + export PYTHONUNBUFFERED=1
# + PYTHONUNBUFFERED=1
# + python -u -m rfconnectorai.data.audit --data-dir training --out docs/DATASET_AUDIT.md
# audit report: docs/DATASET_AUDIT.md
# audit json:   docs/DATASET_AUDIT.json
# + echo '----- audit summary -----'
# ----- audit summary -----
# + head -40 docs/DATASET_AUDIT.md
# # Dataset Audit
#
# - Generated: `2026-05-10T14:58:33.412372+00:00`
# - Data dir: `/content/hotdogornot/training`
# - Roots audited: 5
#
# ## Summary By Root
#
# | Root | Images | Videos | Synthetic | Holdout | Reference | Multi-conn hint | Unreadable |
# |---|---:|---:|---:|---:|---:|---:|---:|
# | `/content/hotdogornot/training/Images` | 55 | 0 | 0 | 0 | 0 | 1 | 0 |
# | `/content/hotdogornot/training/data/labeled` | 13850 | 0 | 0 | 0 | 0 | 0 | 0 |
# | `/content/hotdogornot/training/data/test_holdout` | 8 | 0 | 0 | 8 | 0 | 0 | 0 |
# | `/content/hotdogornot/training/data/reference` | 2 | 0 | 0 | 0 | 2 | 0 | 0 |
# | `/content/hotdogornot/training/data/videos` | 0 | 3 | 0 | 0 | 0 | 0 | 0 |
#
# ## Duplicate Groups (sha256)
#
# - `Images/Sb13fdff1dd1f4fc5841bee47aee102f4F (1).jpg`, `Images/Sb13fdff1dd1f4fc5841bee47aee102f4F.jpg`
# - `Images/Sc0620eb6b3484352ba605af77b62f28cu (1).jpg`, `Images/Sc0620eb6b3484352ba605af77b62f28cu.jpg`
# - `Images/20-Type SMA Adapter Kit – Universal SMA to UHF SO-239 PL-259 N BNC F and SMA view 1.webp`, `Images/20-Type SMA Adapter Kit – Universal SMA to UHF SO-239 PL-259 N BNC F and SMA view 7.webp`
# - `data/labeled/embedder/2.4mm-F/tight_000018.jpg`, `data/labeled/embedder/2.4mm-F/tight_000020.jpg`, `data/labeled/embedder/2.4mm-M/tight_000019.jpg`
# - `data/labeled/embedder/2.4mm-M/video_0011_central.jpg`, `data/labeled/embedder/2.4mm-M/video_0062_central.jpg`
# - `data/labeled/embedder/2.4mm-M/video_0000_centralv2.jpg`, `data/labeled/embedder/2.4mm-M/video_0051_centralv2.jpg`
# - `data/labeled/embedder/2.4mm-M/video_0000.jpg`, `data/labeled/embedder/2.4mm-M/video_0051.jpg`, `data/labeled/embedder/2.4mm-M/video_0067.jpg`
# - `data/labeled/embedder/2.4mm-M/video_0009_z70.jpg`, `data/labeled/embedder/2.4mm-M/video_0060_z70.jpg`
# - `data/labeled/embedder/2.4mm-M/video_0009_centralv2.jpg`, `data/labeled/embedder/2.4mm-M/video_0060_centralv2.jpg`
# - `data/labeled/embedder/2.4mm-M/video_0011_z50.jpg`, `data/labeled/embedder/2.4mm-M/video_0062_z50.jpg`
# - `data/labeled/embedder/2.4mm-M/video_0000_z50.jpg`, `data/labeled/embedder/2.4mm-M/video_0051_z50.jpg`
# - `data/labeled/embedder/2.4mm-F/video_0042.jpg`, `data/labeled/embedder/2.4mm-F/video_0093.jpg`, `data/labeled/embedder/2.4mm-M/video_0191.jpg`
# - `data/labeled/embedder/2.4mm-M/video_0063.jpg`, `data/labeled/embedder/2.4mm-M/video_0102.jpg`
# - `data/labeled/embedder/2.4mm-M/tight_000018.jpg`, `data/labeled/embedder/2.4mm-M/tight_000027.jpg`, `data/labeled/embedder/2.4mm-M/tight_000035.jpg`
# - `data/labeled/embedder/2.4mm-M/video_0009.jpg`, `data/labeled/embedder/2.4mm-M/video_0060.jpg`, `data/labeled/embedder/2.4mm-M/video_0093.jpg`
# - `data/labeled/embedder/2.4mm-F/video_0043.jpg`, `data/labeled/embedder/2.4mm-F/video_0094.jpg`, `data/labeled/embedder/2.4mm-M/video_0192.jpg`
# - `data/labeled/embedder/2.4mm-F/video_0039.jpg`, `data/labeled/embedder/2.4mm-F/video_0090.jpg`, `data/labeled/embedder/2.4mm-M/video_0182.jpg`
# - `data/labeled/embedder/2.4mm-M/synth_001444.jpg`, `data/labeled/embedder/2.92mm-M/synth_000004.jpg`, `data/labeled/embedder/3.5mm-M/synth_001822.jpg`
# - `data/labeled/embedder/2.4mm-M/video_0000_z70.jpg`, `data/labeled/embedder/2.4mm-M/video_0051_z70.jpg`
# - `data/labeled/embedder/2.4mm-M/video_0011_clean.jpg`, `data/labeled/embedder/2.4mm-M/video_0062_clean.jpg`
# - `data/labeled/embedder/2.4mm-F/video_0023.jpg`, `data/labeled/embedder/2.4mm-F/video_0074.jpg`, `data/labeled/embedder/2.4mm-M/video_0131.jpg`
# - `data/labeled/embedder/2.4mm-M/video_0011.jpg`, `data/labeled/embedder/2.4mm-M/video_0062.jpg`, `data/labeled/embedder/2.4mm-M/video_0095.jpg`
# + python -u -m rfconnectorai.data.crop_instances --input training/data/labeled/embedder --manifest datasets/rfconnectors/instances.jsonl --out datasets/rfconnectors/crops --mode whole-image --base-dir training
# whole-image: scanned 13850 images under training/data/labeled/embedder, skipped 0 unreadable, kept 13850
# manifest: datasets/rfconnectors/instances.jsonl (13850 rows)
# crops: datasets/rfconnectors/crops (0 files written)
# + wc -l datasets/rfconnectors/instances.jsonl
# 13850 datasets/rfconnectors/instances.jsonl

# %%
 # %%shell
  set -euxo pipefail
  cd /content/hotdogornot
  export PYTHONPATH=/content/hotdogornot/training
  export PYTHONUNBUFFERED=1

  python -u -m rfconnectorai.data.build_yolo_dataset \
      --input datasets/rfconnectors/instances.jsonl \
      --out datasets/rfconnectors --base-dir training \
      --taxonomy training/rfconnectorai/specs/connectors.yaml

  ls datasets/rfconnectors/
  cat datasets/rfconnectors/data.yaml
  cat datasets/rfconnectors/dataset.lock.json
  find datasets/rfconnectors/images -name "*.jpg" | wc -l
# Out:
# + cd /content/hotdogornot
# + export PYTHONPATH=/content/hotdogornot/training
# + PYTHONPATH=/content/hotdogornot/training
# + export PYTHONUNBUFFERED=1
# + PYTHONUNBUFFERED=1
# + python -u -m rfconnectorai.data.build_yolo_dataset --input datasets/rfconnectors/instances.jsonl --out datasets/rfconnectors --base-dir training --taxonomy training/rfconnectorai/specs/connectors.yaml
# {
#   "created_at": "2026-05-10T14:58:54.161776+00:00",
#   "dataset_id": "rfconnectors_2026_05_10_001",
#   "dry_run": false,
#   "family_to_idx": {
#     "2.4MM": 0,
#     "2.92MM": 1,
#     "3.5MM": 2
#   },
#   "holdout_excluded": true,
#   "instances_sha256": "fbc66582d68a2357b888c016f773f3d0019a8e23b49d2f692e8ce46f28f35ddc",
#   "skipped_count": 0,
#   "split_seed": 1337,
#   "taxonomy_sha256": "c87ddaf7b0e9bbe56a7a2efee62f08744b383ccf7f30575d3286cfde4a85ece7",
#   "test_count": 1322,
#   "train_count": 11117,
#   "val_count": 1411
# }
# + ls datasets/rfconnectors/
# attributes.csv	dataset.lock.json  data.yaml  images  instances.jsonl  labels
# + cat datasets/rfconnectors/data.yaml
# path: /content/hotdogornot/datasets/rfconnectors
# train: /content/hotdogornot/datasets/rfconnectors/images/train
# val: /content/hotdogornot/datasets/rfconnectors/images/val
# test: /content/hotdogornot/datasets/rfconnectors/images/test
# nc: 3
# names:
#   - 2.4MM
#   - 2.92MM
#   - 3.5MM
# + cat datasets/rfconnectors/dataset.lock.json
# {
#   "created_at": "2026-05-10T14:58:54.161776+00:00",
#   "dataset_id": "rfconnectors_2026_05_10_001",
#   "dry_run": false,
#   "family_to_idx": {
#     "2.4MM": 0,
#     "2.92MM": 1,
#     "3.5MM": 2
#   },
#   "holdout_excluded": true,
#   "instances_sha256": "fbc66582d68a2357b888c016f773f3d0019a8e23b49d2f692e8ce46f28f35ddc",
#   "skipped_count": 0,
#   "split_seed": 1337,
#   "taxonomy_sha256": "c87ddaf7b0e9bbe56a7a2efee62f08744b383ccf7f30575d3286cfde4a85ece7",
#   "test_count": 1322,
#   "train_count": 11117,
#   "val_count": 1411
# }+ find datasets/rfconnectors/images -name '*.jpg'
# + wc -l
# 5351

# %%
# %%shell
# set -euxo pipefail
# cd /content/hotdogornot
# export PYTHONPATH=/content/hotdogornot/training
# export PYTHONUNBUFFERED=1
#
# python -u -m rfconnectorai.detector.train_yolo \
#     --data datasets/rfconnectors/data.yaml --model yolo11n.pt \
#     --epochs 5 --imgsz 640 --batch 96 --device 0 \
#     --dataset-lock datasets/rfconnectors/dataset.lock.json \
#     --out reports/experiments/detector_run_full \
#     --artifact-out models/detector
# Out:
# + cd /content/hotdogornot
# + export PYTHONPATH=/content/hotdogornot/training
# + PYTHONPATH=/content/hotdogornot/training
# + export PYTHONUNBUFFERED=1
# + PYTHONUNBUFFERED=1
# + python -u -m rfconnectorai.detector.train_yolo --data datasets/rfconnectors/data.yaml --model yolo11n.pt --epochs 5 --imgsz 640 --batch 96 --device 0 --dataset-lock datasets/rfconnectors/dataset.lock.json --out reports/experiments/detector_run_full --artifact-out models/detector
# Ultralytics 8.4.48 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=96, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/hotdogornot/datasets/rfconnectors/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=5, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=connector, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/hotdogornot/reports/experiments/detector_run_full/ultralytics, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431257  ultralytics.nn.modules.head.Detect           [3, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,425 parameters, 2,590,409 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 725.8±774.8 MB/s, size: 54.1 KB)
# train: Scanning /content/hotdogornot/datasets/rfconnectors/labels/train.cache... 11117 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 11117/11117 1.4Git/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 119.4±60.8 MB/s, size: 2.7 KB)
# val: Scanning /content/hotdogornot/datasets/rfconnectors/labels/val.cache... 1411 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1411/1411 64.3Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.00075), 87 bias(decay=0.0)
# Plotting labels to /content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5      12.5G     0.2229      1.812      1.008        242        640: 100% ━━━━━━━━━━━━ 116/116 2.1s/it 4:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.9s/it 23.1s
#                    all       1411       1411      0.451      0.479      0.532      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5      12.1G     0.1015     0.8433     0.9132        221        640: 100% ━━━━━━━━━━━━ 116/116 1.7s/it 3:15
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.4s/it 26.9s
#                    all       1411       1411      0.807      0.771      0.901      0.864
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/5      12.1G     0.1001     0.6856     0.9086        225        640: 100% ━━━━━━━━━━━━ 116/116 1.7s/it 3:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.2s/it 25.6s
#                    all       1411       1411      0.452      0.521      0.484      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/5      12.1G    0.08227     0.5794     0.9025        221        640: 100% ━━━━━━━━━━━━ 116/116 1.7s/it 3:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.9s/it 23.3s
#                    all       1411       1411       0.91      0.832       0.96      0.941
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/5      12.1G    0.06094     0.4867     0.8974        230        640: 100% ━━━━━━━━━━━━ 116/116 1.7s/it 3:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.8s/it 22.6s
#                    all       1411       1411      0.983      0.865      0.979      0.975
#
# 5 epochs completed in 0.321 hours.
# Optimizer stripped from /content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/weights/last.pt, 5.5MB
# Optimizer stripped from /content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/weights/best.pt, 5.5MB
#
# Validating /content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/weights/best.pt...
# Ultralytics 8.4.48 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n summary (fused): 101 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.3s/it 26.6s
#                    all       1411       1411      0.983      0.864      0.979      0.974
#                  2.4MM        472        472      0.976      0.907       0.98      0.976
#                 2.92MM        378        378      0.994      0.822      0.975      0.967
#                  3.5MM        561        561       0.98      0.865      0.982       0.98
# Speed: 0.2ms preprocess, 4.5ms inference, 0.0ms loss, 4.5ms postprocess per image
# Results saved to /content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector
# detector best weights: models/detector/best.pt
# run metadata: reports/experiments/detector_run_full

# %%
# !zip -r /content/detector_run_full.zip \
    /content/hotdogornot/reports/experiments/detector_run_full/ \
    /content/hotdogornot/models/detector/best.pt

from google.colab import files
files.download('/content/detector_run_full.zip')
# Out:
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/ (stored 0%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/labels.jpg (deflated 55%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/confusion_matrix.png (deflated 29%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/train_batch1.jpg (deflated 10%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/train_batch2.jpg (deflated 20%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/confusion_matrix_normalized.png (deflated 26%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/BoxP_curve.png (deflated 14%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/val_batch2_pred.jpg (deflated 20%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/BoxPR_curve.png (deflated 21%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/BoxF1_curve.png (deflated 13%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/val_batch0_pred.jpg (deflated 23%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/weights/ (stored 0%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/weights/best.pt (deflated 10%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/weights/last.pt (deflated 10%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/results.csv (deflated 56%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/train_batch0.jpg (deflated 21%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/val_batch1_pred.jpg (deflated 23%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/args.yaml (deflated 54%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/results.png (deflated 7%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/BoxR_curve.png (deflated 13%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/val_batch0_labels.jpg (deflated 22%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/val_batch2_labels.jpg (deflated 19%)
# updating: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/val_batch1_labels.jpg (deflated 23%)
# updating: content/hotdogornot/models/detector/best.pt (deflated 10%)
#   adding: content/hotdogornot/reports/experiments/detector_run_full/ (stored 0%)
#   adding: content/hotdogornot/reports/experiments/detector_run_full/ultralytics/ (stored 0%)
#   adding: content/hotdogornot/reports/experiments/detector_run_full/model_record.json (deflated 42%)
#   adding: content/hotdogornot/reports/experiments/detector_run_full/config.json (deflated 40%)

# %%
# Check which runs exist and their sizes
# !ls -la /content/hotdogornot/reports/experiments/
# !wc -l /content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/results.csv
# !cat /content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/results.csv
# Out:
# total 16
# drwxr-xr-x 4 root root 4096 May 10 16:02 .
# drwxr-xr-x 3 root root 4096 May 10 14:59 ..
# drwxr-xr-x 3 root root 4096 May 10 15:39 detector_run_001
# drwxr-xr-x 3 root root 4096 May 10 16:02 detector_run_full
# 6 /content/hotdogornot/reports/experiments/detector_run_full/ultralytics/connector/results.csv
# epoch,time,train/box_loss,train/cls_loss,train/dfl_loss,metrics/precision(B),metrics/recall(B),metrics/mAP50(B),metrics/mAP50-95(B),val/box_loss,val/cls_loss,val/dfl_loss,lr/pg0,lr/pg1,lr/pg2
# 1,272.308,0.22292,1.81176,1.00814,0.45142,0.47871,0.53226,0.37769,0.593,2.22004,0.63305,0.000472227,0.000472227,0.000472227
# 2,496.66,0.1015,0.84327,0.91316,0.80668,0.77106,0.90102,0.86376,0.25851,1.08784,0.33686,0.000760745,0.000760745,0.000760745
# 3,718.536,0.10006,0.6856,0.90861,0.45249,0.52139,0.48401,0.41399,0.46543,3.18782,0.63689,0.000860636,0.000860636,0.000860636
# 4,936.578,0.08227,0.57937,0.90251,0.90989,0.83175,0.95982,0.94085,0.26688,0.62356,0.35002,0.000580174,0.000580174,0.000580174
# 5,1154.43,0.06094,0.48665,0.89743,0.98329,0.86493,0.97909,0.97468,0.25424,0.49023,0.35817,0.000297232,0.000297232,0.000297232
